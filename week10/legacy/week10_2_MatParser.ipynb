# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os

mat_path = '/home/wins057/Documents/Projects/python-for-dl-homework/week10/dataset/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/ground_truth/GT_IMG_1.mat'

# parsing .mat file
mat = scipy.io.loadmat(mat_path)
points = mat['image_info'][0, 0][0, 0][0]  # 通常是這樣存取 nested struct

# load people counter
print(f"People count: {len(points)}")
#print("first 5 people positions:")
#print(points[:5])


# load image
image_path = '/home/wins057/Documents/Projects/python-for-dl-homework/week10/dataset/ShanghaiTech_Crowd_Counting_Dataset/part_A_final/test_data/images/IMG_1.jpg'
img = plt.imread(image_path)


# show image
plt.figure(figsize=(10, 8))
plt.imshow(img)
#plt.axis('off')
plt.show()
# Out:
# People count: 172
